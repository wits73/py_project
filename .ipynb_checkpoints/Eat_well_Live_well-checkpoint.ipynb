# %% [markdown]
# # 1. Introduction
# You are viewing the README file that accompanies data extracted from the US Food and Drug Administration (FDA) Center for Food Safety and Applied Nutrition (CFSAN) Adverse Event Reporting System (CAERS).

# %% [markdown]
# ## 1.1 Data Fields
# - RA_Report # : Unique#
# - RA_CAERS Created Date : Data were first entered into CAERS from an adverse event report
# - AEC_Event Start Date : The reported date on which the consumer first experienced the adverse event.
# - PRI_Product Role : Suspect or concomitant (as reported)
# - PRI_Reported Brand/Product Name : The verbatim brands and/or product names indicated to have been used by the consumer reported to have experienced the adverse event.
# - PRI_FDA Industry Code : The FDA industry code associated with the type of product reported.
# - PRI_FDA Industry Name : The FDA industry description associated with the type of product reported.
# - CI_Age at Adverse Event : The age of the consumer reported to have experienced the adverse event.
# - CI_Age Unit : The time unit
# - CI_Gender : The sex of the individual reported to have experienced the adverse event.
# - AEC_One Row Outcomes : Outcome(s) of the adverse event experienced by the injured consumer as specified by the reporter;
# - SYM_One Row Coded Symptoms : The symptom(s) experienced by the injured consumer as specified by the reporter

# %%
#%matplotlib nbagg #inline, nbagg
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline 
#inline, nbagg

# %%
df_base = pd.read_csv('data/adverse-food-events/CAERS_ASCII_2004_2017Q2.csv')

# %%
df_base.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90786 entries, 0 to 90785
# Data columns (total 12 columns):
# RA_Report #                        90786 non-null int64
# RA_CAERS Created Date              90786 non-null object
# AEC_Event Start Date               53653 non-null object
# PRI_Product Role                   90786 non-null object
# PRI_Reported Brand/Product Name    90786 non-null object
# PRI_FDA Industry Code              90786 non-null int64
# PRI_FDA Industry Name              90786 non-null object
# CI_Age at Adverse Event            52926 non-null float64
# CI_Age Unit                        90786 non-null object
# CI_Gender                          90786 non-null object
# AEC_One Row Outcomes               90786 non-null object
# SYM_One Row Coded Symptoms         90781 non-null object
# dtypes: float64(1), int64(2), object(9)
# memory usage: 8.3+ MB

# %%
df_base.head()
# Out:
#    RA_Report # RA_CAERS Created Date AEC_Event Start Date PRI_Product Role  \
# 0        65325              1/1/2004             8/4/2003          Suspect
# 1        65325              1/1/2004             8/4/2003          Suspect
# 2        65333              1/1/2004                  NaN          Suspect
# 3        65335              1/1/2004           11/24/2003          Suspect
# 4        65336              1/1/2004                  NaN          Suspect
#
#                      PRI_Reported Brand/Product Name  PRI_FDA Industry Code  \
# 0      MIDWEST COUNTRY FAIR CHOCOLATE FLAVORED CHIPS                      3
# 1      MIDWEST COUNTRY FAIR CHOCOLATE FLAVORED CHIPS                      3
# 2  KROGER CLASSIC CREAM-DE-MINT CANDY MINT CHIP I...                     13
# 3                         ENFAMIL LIPIL BABY FORMULA                     40
# 4                         ENFIMIL LIPIL BABY FORMULA                     40
#
# ...

# %% [markdown]
# ## 1.2 Data Cleansing
# ### 1.2.1 Remove duplicated RA_Report

# %%
# Just in Case
df_drop_dup = df_base.drop_duplicates(['RA_Report #'], keep=False)
df_rm_dup_keep_last = df_base.drop_duplicates(['RA_Report #'], keep='last')

# %%
df_rm_dup_keep_last.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 64517 entries, 1 to 90785
# Data columns (total 12 columns):
# RA_Report #                        64517 non-null int64
# RA_CAERS Created Date              64517 non-null object
# AEC_Event Start Date               36935 non-null object
# PRI_Product Role                   64517 non-null object
# PRI_Reported Brand/Product Name    64517 non-null object
# PRI_FDA Industry Code              64517 non-null int64
# PRI_FDA Industry Name              64517 non-null object
# CI_Age at Adverse Event            32221 non-null float64
# CI_Age Unit                        64517 non-null object
# CI_Gender                          64517 non-null object
# AEC_One Row Outcomes               64517 non-null object
# SYM_One Row Coded Symptoms         64512 non-null object
# dtypes: float64(1), int64(2), object(9)
# memory usage: 6.4+ MB

# %%
df_rm_dup_keep_last.head()
# Out:
#    RA_Report # RA_CAERS Created Date AEC_Event Start Date PRI_Product Role  \
# 1        65325              1/1/2004             8/4/2003          Suspect
# 2        65333              1/1/2004                  NaN          Suspect
# 3        65335              1/1/2004           11/24/2003          Suspect
# 4        65336              1/1/2004                  NaN          Suspect
# 5        65345              1/1/2004           12/21/2003          Suspect
#
#                      PRI_Reported Brand/Product Name  PRI_FDA Industry Code  \
# 1      MIDWEST COUNTRY FAIR CHOCOLATE FLAVORED CHIPS                      3
# 2  KROGER CLASSIC CREAM-DE-MINT CANDY MINT CHIP I...                     13
# 3                         ENFAMIL LIPIL BABY FORMULA                     40
# 4                         ENFIMIL LIPIL BABY FORMULA                     40
# 5        FRITO LAY FUNYUNS ONION FLAVOR, ONION RINGS                      7
#
# ...

# %% [markdown]
# ### 1.2.1 Remove space to Product Name, Industry Name, Outcomes and Symptoms

# %%
#df_rm_dup_keep_last['PRI_Reported Brand/Product Name']=df_rm_dup_keep_last.loc[:,'PRI_Reported Brand/Product Name'].str.strip()
df_rm_dup_keep_last['PRI_Reported Brand/Product Name'] = df_rm_dup_keep_last['PRI_Reported Brand/Product Name'].str.strip()
#df_rm_dup_keep_last['PRI_FDA Industry Name'] = df_rm_dup_keep_last['PRI_FDA Industry Name'].str.strip()
#df_rm_dup_keep_last['AEC_One Row Outcomes'] = df_rm_dup_keep_last['AEC_One Row Outcomes'].str.strip()
#df_rm_dup_keep_last['SYM_One Row Coded Symptoms'] = df_rm_dup_keep_last['SYM_One Row Coded Symptoms'].str.strip()
# Out:
# C:\Users\TaeWoo\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# ### Create new data set for PRI_Reported Brand/Product Name

# %%
group_product = df_rm_dup_keep_last.groupby('PRI_Reported Brand/Product Name')

# %%
df_product_cnt = pd.DataFrame({'count' : group_product.size()}).reset_index()

# %%
df_product_cnt.sort_values('count', ascending=False, inplace=True)

# %%
df_product_cnt.head()
# Out:
#                          PRI_Reported Brand/Product Name  count
# 26306                                           REDACTED   6078
# 4833   CENTRUM SILVER WOMEN'S 50+ (MULTIMINERALS, MUL...    600
# 30164                                SUPER BETA PROSTATE    536
# 33550                          WEN CLEANSING CONDITIONER    355
# 23210                     PETER PAN CREAMY PEANUT BUTTER    324

# %%
df_product_cnt.drop([26306], inplace=True)

# %%
df_product_cnt.head()
# Out:
#                          PRI_Reported Brand/Product Name  count
# 4833   CENTRUM SILVER WOMEN'S 50+ (MULTIMINERALS, MUL...    600
# 30164                                SUPER BETA PROSTATE    536
# 33550                          WEN CLEANSING CONDITIONER    355
# 23210                     PETER PAN CREAMY PEANUT BUTTER    324
# 13927           HYDROXYCUT REGULAR RAPID RELEASE CAPLETS    308

# %% [markdown]
# ### Create new data set for PRI_FDA Industry Name

# %%
group_industry = df_rm_dup_keep_last.groupby('PRI_FDA Industry Name')

# %%
df_industry_cnt = pd.DataFrame({'count' : group_industry.size()}).reset_index()

# %%
df_industry_cnt.sort_values('count', ascending=False, inplace=True)

# %%
df_industry_cnt.head()
# Out:
#                      PRI_FDA Industry Name  count
# 38  Vit/Min/Prot/Unconv Diet(Human/Animal)  26594
# 10                               Cosmetics  10698
# 29                        Nuts/Edible Seed   3312
# 37           Vegetables/Vegetable Products   2707
# 32                        Soft Drink/Water   2380

# %% [markdown]
# ### Create new data set for AEC_One Row Outcomes

# %%
group_outcomes = df_rm_dup_keep_last.groupby('AEC_One Row Outcomes')

# %%
df_outcomes_cnt = pd.DataFrame({'count':group_outcomes.size()}).reset_index()

# %%
df_outcomes_cnt.sort_values('count', ascending=False, inplace=True)

# %%
df_outcomes_cnt.head()
# Out:
#                                   AEC_One Row Outcomes  count
# 176                      NON-SERIOUS INJURIES/ ILLNESS  21241
# 189           OTHER SERIOUS (IMPORTANT MEDICAL EVENTS)  13816
# 232  VISITED A HEALTH CARE PROVIDER, OTHER SERIOUS ...   5168
# 120                                    HOSPITALIZATION   3188
# 225                     VISITED A HEALTH CARE PROVIDER   2548

# %% [markdown]
# ### Create new data set for SYM_One Row Coded Symptoms

# %%
group_symptoms = df_rm_dup_keep_last.groupby('SYM_One Row Coded Symptoms')

# %%
group_symptoms.size()
# Out:
# SYM_One Row Coded Symptoms
# ABASIA                                                                                                                                                                                                                                                                                   1
# ABASIA, ABASIA                                                                                                                                                                                                                                                                           1
# ABASIA, ANAPHYLACTIC REACTION                                                                                                                                                                                                                                                            1
# ...

# %%
lst_symtoms = []
#for _, reactions in df_base['SYM_One Row Coded Symptoms'].str.split(",").iteritems():
#    outcomes += [l.strip().title() for l in reactions]
#outcomes

for _, pd_series in df_rm_dup_keep_last['SYM_One Row Coded Symptoms'].str.split(",").iteritems():
    lst_symtoms += [str(l).strip().title() for l in pd.Series(pd_series)] 
df_symptoms = pd.DataFrame({'outcome':pd.Series(lst_symtoms).value_counts().index,
                         'count':pd.Series(lst_symtoms).value_counts()})[:]

# %%
df_symptoms.head()
# Out:
#                 count         outcome
# Diarrhoea       12303       Diarrhoea
# Vomiting        10368        Vomiting
# Nausea           8762          Nausea
# Abdominal Pain   7319  Abdominal Pain
# Malaise          4956         Malaise

# %% [markdown]
# ### Check Gender

# %%
df_rm_dup_keep_last['CI_Gender'].unique()
# Out:
# array(['Female', 'Not Available', 'Male', 'Unknown', 'Not Reported'], dtype=object)

# %%
#df_base.loc[(df_base['CI_Gender'] == 'Unknown') | (df_base['CI_Gender'] == 'Not Reported') , :]
df_rm_dup_keep_last['CI_Gender'].replace('Unknown','Not Available', inplace=True)
df_rm_dup_keep_last['CI_Gender'].replace('Not Reported','Not Available', inplace=True)
# Out:
# C:\Users\TaeWoo\Anaconda3\lib\site-packages\pandas\core\generic.py:3924: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %%
df_rm_dup_keep_last['CI_Gender'].unique()
# Out:
# array(['Female', 'Not Available', 'Male'], dtype=object)

# %% [markdown]
# ## Drawing Graph

# %%
df_product_cnt.head()
# Out:
#                          PRI_Reported Brand/Product Name  count
# 4833   CENTRUM SILVER WOMEN'S 50+ (MULTIMINERALS, MUL...    600
# 30164                                SUPER BETA PROSTATE    536
# 33550                          WEN CLEANSING CONDITIONER    355
# 23210                     PETER PAN CREAMY PEANUT BUTTER    324
# 13927           HYDROXYCUT REGULAR RAPID RELEASE CAPLETS    308

# %%
#fig, ax = plt.subplots(figsize=(8,14))
#product_count=df.groupby('PRI_Reported Brand/Product Name').size()
#product_count_large = df_product_cnt.loc[:,df_product_cnt.count > 100 ]
#print(product_count_large)
#product_count_df=pd.DataFrame({'product':product_count_large.index,'count':product_count_large}, index=None)
#new=product_count_df.merge(df[['PRI_Reported Brand/Product Name','PRI_FDA Industry Name']],how='inner', left_on='product', right_on='PRI_Reported Brand/Product Name').drop_duplicates()[['count','product','PRI_FDA Industry Name']]
#sns.barplot(x='count',y='product',hue='PRI_FDA Industry Name',data=new,dodge=False).set_title("Products with more than 150 health events")

# %%
df_industry_cnt.head()
# Out:
#                      PRI_FDA Industry Name  count
# 38  Vit/Min/Prot/Unconv Diet(Human/Animal)  26594
# 10                               Cosmetics  10698
# 29                        Nuts/Edible Seed   3312
# 37           Vegetables/Vegetable Products   2707
# 32                        Soft Drink/Water   2380

# %%
industry_cnt = df_rm_dup_keep_last['PRI_FDA Industry Name'].value_counts()

# %%
industry_cnt
# Out:
# Vit/Min/Prot/Unconv Diet(Human/Animal)    26594
# Cosmetics                                 10698
# Nuts/Edible Seed                           3312
# Vegetables/Vegetable Products              2707
# Soft Drink/Water                           2380
# Bakery Prod/Dough/Mix/Icing                2358
# Fishery/Seafood Prod                       2116
# Fruit/Fruit Prod                           2026
# Milk/Butter/Dried Milk Prod                1385
# Cereal Prep/Breakfast Food                 1134
# Baby Food Prod                             1122
# Dietary Conv Food/Meal Replacements         947
# Snack Food Item                             929
# Mult Food Dinner/Grav/Sauce/Special         904
# Ice Cream Prod                              784
# Choc/Cocoa Prod                             696
# Coffee/Tea                                  683
# Candy W/O Choc/Special/Chew Gum             582
# Cheese/Cheese Prod                          341
# Whole Grain/Milled Grain Prod/Starch        315
# ...

# %%
value = industry_cnt.values
index = industry_cnt.index
df_sns = pd.DataFrame(dict(Count=value, IndustryName=index))

# %%
sns.set_style("whitegrid") # darkgrid, whitegrid, dark, white, ticks
#sns.barplot("count","name", data=df_sns, palette="Blues_d");
sns.factorplot("Count","IndustryName", data=df_sns,kind="bar",palette="winter",size=7,aspect=1.5,legend_out=False)

# %%
industry_cnt
# Out:
# Alcoholic Beverage                           21
# Baby Food Prod                             1122
# Bakery Prod/Dough/Mix/Icing                2358
# Beverage Bases/Conc/Nectar                  134
# Candy W/O Choc/Special/Chew Gum             582
# Cereal Prep/Breakfast Food                 1134
# Cheese/Cheese Prod                          341
# Choc/Cocoa Prod                             696
# Coffee/Tea                                  683
# Color Additiv Food/Drug/Cosmetic             11
# Cosmetics                                 10698
# Dietary Conv Food/Meal Replacements         947
# Dressing/Condiment                          210
# Egg/Egg Prod                                180
# Filled Milk/Imit Milk Prod                  212
# Fishery/Seafood Prod                       2116
# Food Additives (Human Use)                  260
# Food Service/Conveyance                      12
# Food Sweeteners (Nutritive)                 207
# Fruit/Fruit Prod                           2026
# ...

# %%
#industry_cnt.plot(kind='bar')
industry_cnt.plot(kind='barh')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#rc={'axes.labelsize': 15, 'font.size': 15, 'legend.fontsize': 15, 'axes.titlesize': 15}
#fig, ax = plt.subplots(figsize=(8,12))  # this creates a figure 8 inch wide, 44 inch high
#plt.yticks(rotation=20, fontsize=5)
#fig = plt.figure()
#ax = fig.add_subplot(111)
#ax.yaxis.tick_right()
#plt.rcParams.update(**rc)
#sns.set_style("whitegrid") # darkgrid, whitegrid, dark, white, ticks
#tips = sns.load_dataset(industry_cnt)
#sns.barplot( x='xtest', y='y', data=tips).set_title('Health Event Counts')

sns.set_style("whitegrid")
sns.barplot(x="day", y="total_bill", data=industry_cnt)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-178-9066528ecd02> in <module>()
#      11
#      12 sns.set_style("whitegrid")
# ---> 13 sns.barplot(x="day", y="total_bill", data=industry_cnt)
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    2938                           estimator, ci, n_boot, units,
#    2939                           orient, color, palette, saturation,
# -> 2940                           errcolor, errwidth, capsize, dodge)
#    2941
#    2942     if ax is None:
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge)
# ...

# %%
sns.countplot(df_rm_dup_keep_last['CI_Gender'])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df_base.head()
# Out:
#    RA_Report # RA_CAERS Created Date AEC_Event Start Date PRI_Product Role  \
# 0        65325              1/1/2004             8/4/2003          Suspect
# 1        65325              1/1/2004             8/4/2003          Suspect
# 2        65333              1/1/2004                  NaN          Suspect
# 3        65335              1/1/2004           11/24/2003          Suspect
# 4        65336              1/1/2004                  NaN          Suspect
#
#                      PRI_Reported Brand/Product Name  PRI_FDA Industry Code  \
# 0      MIDWEST COUNTRY FAIR CHOCOLATE FLAVORED CHIPS                      3
# 1      MIDWEST COUNTRY FAIR CHOCOLATE FLAVORED CHIPS                      3
# 2  KROGER CLASSIC CREAM-DE-MINT CANDY MINT CHIP I...                     13
# 3                         ENFAMIL LIPIL BABY FORMULA                     40
# 4                         ENFIMIL LIPIL BABY FORMULA                     40
#
# ...

# %%
#symptom_list = df_base['SYM_One Row Coded Symptoms'].str.get_dummies(sep=',')
#symptom_list = df_base['SYM_One Row Coded Symptoms'].tolist()
#symptom_list.replace('\'','',inplace=True)
#symptom_list

#df_symtoms = df_base['SYM_One Row Coded Symptoms'].uniq
#symptom_list = df_symtoms.tolist()
#df_test = df_base.loc[0:20, :]
#df_test['SYM_One Row Coded Symptoms'].str.get_dummies(sep=',')
df_concat = pd.concat([df_base, df_base['SYM_One Row Coded Symptoms'].str.get_dummies(sep=',')], axis=1)
df_concat.columns
# Out:
# Index(['RA_Report #', 'RA_CAERS Created Date', 'AEC_Event Start Date',
#        'PRI_Product Role', 'PRI_Reported Brand/Product Name',
#        'PRI_FDA Industry Code', 'PRI_FDA Industry Name',
#        'CI_Age at Adverse Event', 'CI_Age Unit', 'CI_Gender',
#        ...
#        'WOUND DRAINAGE', 'WOUND HAEMORRHAGE', 'WOUND INFECTION',
#        'WOUND SECRETION', 'WRIST FRACTURE',
#        'WRONG TECHNIQUE IN DRUG USAGE PROCESS', 'X-RAY', 'YAWNING',
#        'YELLOW SKIN', 'YERSINIA INFECTION'],
#       dtype='object', length=5874)

# %%
#df_base.to_csv
#df_base.to_csv('data/adverse-food-events.csv',sep=',')
df_mody = pd.read_csv('data/adverse-food-events.csv')
df_mody.info()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens (pandas\_libs\parsers.c:14858)()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype (pandas\_libs\parsers.c:17119)()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._string_convert (pandas\_libs\parsers.c:17347)()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers._string_box_utf8 (pandas\_libs\parsers.c:23041)()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xa2 in position 7: invalid start byte
#
# During handling of the above exception, another exception occurred:
#
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-46-62df939046e0> in <module>()
#       1 #df_base.to_csv
#       2 #df_base.to_csv('data/adverse-food-events.csv',sep=',')
# ...
